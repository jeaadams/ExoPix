# %%
import os
import astropy.io.fits as fits
import numpy as np
import scipy
import scipy.ndimage as ndi
import matplotlib.pylab as plt
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pyklip.klip
import pyklip.instruments.Instrument as Instrument
import pyklip.parallelized as parallelized
import pyklip.rdi as rdi

# %%
mask210 = pd.read_csv("MASK210R.csv")

# %%
plt.figure(figsize = (10,7))
plt.plot(mask210["fractrans"], mask210["perpdist "])
plt.title("Transmission Profile for MASK210 Coronagraph")
plt.ylabel("Fractional Transmission")
plt.xlabel("Perpendicular Distance (arcsec)")
plt.rcParams.update({'font.size': 18})
